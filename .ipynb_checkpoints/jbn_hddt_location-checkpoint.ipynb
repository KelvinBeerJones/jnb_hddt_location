# %% [markdown]
# # HDDT Locations #

# %% [markdown]
# ## An analysis of the locations associated with members of the CEDA 1830 -1870 ##

# %% [markdown]
# <img src="locationsdemo.png">

# %% [markdown]
# # Introduction #
#
# 1881 members of the community are recorded as members of 81 locations and each of these locations constitutes a locality where meetings between members may take place, equally they may also be places where members might meet up infrequently. The extent of connectivity between the locations indicates the extent that the community is geographically connected. The 1881 are 61% of the community. The above graph shows the 1881 distributed geographically with the connectivity between them reflected in those members who have been associeated with more that one location.

# %%
# First we call up the python packages we need to perform the analysis:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(20, 10))
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately.
import nbconvert
import csv

# %% [markdown]
# ## This is an iterative workbook ##
#
# As can be seen in the illustrative graph above which has been produced in Gephi to provide an initial overview of the data and its distribution, the graph might be more meaningful if it did not include locations sparsely populated.
#
# The code cell below has been designed so that a second run through the workbook can be made where the second run uses data that excludes low poputated areas.

# %%
# Second we call up the csv files generated from the SQL database that contain information about 
# locations and the community members associated with locations. As well as enabling the locations to be listed 
# we produce a 'node_names' file and a tuples file of edges_attributes to generate the files need to 
# produce GefX files for Gephi.

# We can run the code cell twice, first with all data and once all data has been examined
# and a decision made to exclude 'noise' the code block can be run again with newly generated 
# csv files that exclude low populated locations.

location = pd.read_csv ('location_202107221303.csv')

# Use these csv files in the 'with open' statements below to generate locations.gexf
names = pd.read_csv ('vw_3_location_names_1_2_202107221500.csv')# For nodes csv
tuples = pd.read_csv ('vw_2_location_membership_xid_202107221527.csv')# For edges.csv

# Use these csv files in the 'with open' statements below to generate locations_10.gexf
location_10_names = pd.read_csv ('vw_location_10_names_1_2_202107231036.csv') # For nodes csv
location_10_tuples = pd.read_csv ('vw_location_10_202107231013.csv') # For edges.csv


with open('vw_2_location_membership_xid_202107221527.csv', 'r') as nodecsv: # Open the Nodes csv file
    nodereader = csv.reader(nodecsv) # Read the csv
    nodes = [n for n in nodereader][1:]# Retrieve the data (using Python list comprhension and list slicing
                                       # to remove the header row
    node_names = [n[0] for n in nodes] # Get a list of only the node names

with open('vw_location_10_202107231013.csv', 'r') as edgecsv: # Open the file
    edgereader = csv.reader(edgecsv) # Read the csv
    edge_list = list(edgereader) # Convert to list, so can iterate below in for loop
    
    # Create empty arrays to store edge data and edge attribute data
    edges = []
    edges_attributes = []
    
    # Fill the arrays with data from CSV
    for e in edge_list[1:]:
        edges.append(tuple(e[0:2])) # Get the first 2 columns (source, target) and add to array
        # not used this time. edges_attributes.append(tuple(e[2:4])) 
        # Get the 3rd and 4th columns (first_year, last_year) and add to array
    
edge_names = [e[0] for e in edges] # Get a list of only the edge names

# %% [markdown]
# ## We begin by listing out and validating the data ##

# %%
# List out the locations to be analysed

location
# Out:
#     id        name  notes
# 0    1      London    NaN
# 1    3     country    NaN
# 2    4      Africa    NaN
# 3    5     America    NaN
# 4    6    Scotland    NaN
# ..  ..         ...    ...
# 78  80  Madagascar    NaN
# 79  81     Ecuador    NaN
# 80  82  Seychelles    NaN
# 81  83      Panama    NaN
# 82  84     Armenia    NaN
#
# [83 rows x 3 columns]

# %%
# List out the community members who have been associated with at least one location.

names
# Out:
#                        Name
# 0        A  Mackintosh Shaw
# 1            A , jun Ramsay
# 2               A A Stewart
# 3                 A B Stark
# 4               A C Brebner
# ...                     ...
# 1876  x Tumangung of Jehore
# 1877   x University Library
# 1878             x Wagstaff
# 1879             x Wienecke
# 1880               x Zohrab
#
# [1881 rows x 1 columns]

# %%
# Finally list out the tuples of members and locations 
# (Note - some members are associated with more that one location)

tuples
# Out:
#                         Source   Target
# 0     Arthur William A Beckett   London
# 1           Andrew Mercer Adam  country
# 2                     H R Adam   Africa
# 3             Henry John Adams   London
# 4            William (2) Adams   London
# ...                        ...      ...
# 2056              James A Youl   London
# 2057             Robert Younge  country
# 2058         Arthur de Zeltner   Panama
# 2059                  x Zohrab  Armenia
# 2060                  x Zohrab   Turkey
#
# [2061 rows x 2 columns]

# %% [markdown]
# ## Use pyplot to make an inital visualisation of the data ##
#
# We can see that many locations are thinly populaled.
#
# We can also see that locations which might be characterised as parts of the British Empire dominate with locations also found in prominent cities in other colonialist centres (the US, France, Germany).

# %%
tuples.groupby('Target')['Source'].nunique().plot(kind='pie')
plt.title ("Location id")
plt.xlabel ("Locations")
plt.ylabel ("Number of persons")
plt.show()

# %% [markdown]
# ## We can now prepare the data for rendering as a graph in Gephi ##

# %%
print("Nodes length: ", len(node_names))
print("Edges length: ", len(edges))
# not used this time. print("Edges attributes length: ", len(edges_attributes)) # This should be the same length as edges
# Out:
# Nodes length:  2061
# Edges length:  1790

# %%
# First check that the data is correctly formatted

print("First 5 nodes:", node_names[0:5])
print("First 5 edges:", edges[0:5])
# not used this time. print("First 5 edges attributes:", edges_attributes[0:5])

# The output will appear below this code cell.
# Out:
# First 5 nodes: ['Arthur William A Beckett', 'Andrew Mercer Adam', 'H R Adam', 'Henry John Adams', 'William (2) Adams']
# First 5 edges: [('Arthur William A Beckett', 'London'), ('Andrew Mercer Adam', 'country'), ('H R Adam', 'Africa'), ('Henry John Adams', 'London'), ('William (2) Adams', 'London')]

# %%
# We use NetworkX to build the graph data into a table

G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edges)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 1808
# Number of edges: 1790
# Average degree:   1.9801

# %%
# Finally we can write a gexf file which will be placed in the root directory.
# We can then open the file in Gephi and visualise the network.

nx.write_gexf(G, 'locations.gexf')

# %% [markdown]
# ## Stage 2 - with 'noise' removed - low populated locations excluded. ##
#
# We can re-run the exercise using another pair of Names and Tuples files generated in the SQL database where we include only the top 10 locations.

# %%
location_10_names
# Out:
#                       Name
# 0       A  Mackintosh Shaw
# 1           A , jun Ramsay
# 2              A A Stewart
# 3                A B Stark
# 4              A C Brebner
# ...                    ...
# 1617          x Strangford
# 1618             x Tinsley
# 1619  x University Library
# 1620            x Wagstaff
# 1621            x Wienecke
#
# [1622 rows x 1 columns]

# %%
location_10_tuples
# Out:
#                         Source   Target
# 0     Arthur William A Beckett   London
# 1           Andrew Mercer Adam  country
# 2                     H R Adam   Africa
# 3             Henry John Adams   London
# 4            William (2) Adams   London
# ...                        ...      ...
# 1785              Ashton Yates  country
# 1786            James Yearsley  country
# 1787           Stephen Yeldham   London
# 1788              James A Youl   London
# 1789             Robert Younge  country
#
# [1790 rows x 2 columns]

# %% [markdown]
# ## We now have a visualisable dataset that can be analysed ##

# %%
location_10_tuples.groupby('Target')['Source'].nunique().plot(kind='pie')
plt.title ("Location id")
plt.xlabel ("Locations")
plt.ylabel ("Number of persons")
plt.show()

# %% [markdown]
# <img src="location_10.png">

# %% [markdown]
# We can see that London and the (sic) country (The rest of the UK)dominate, we can call this the twin centre. Between the twin centres we can see the members of both satellite groups. the satellite groups are themselves highkly networked. Eight other location each have a membership of around 30 members (we can call these the satellites), none of whom relate directly to the twin centre.
#
# Germany (far right) is the least networked group. Alex Nidda Genthe is the only member from germany who also is amember of the London group. Friedrich Max Muller, Frederick Augustus Haverick and Gustav Oppert each network with country members. William Wilson Hunter appears to be the country member member who has networks in Germany. He and Gustav oppert also have a network connection with India.
